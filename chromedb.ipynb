# %%
pip install chromadb
# Out:
# Collecting chromadbNote: you may need to restart the kernel to use updated packages.
#
#   Downloading chromadb-1.5.9-cp39-abi3-win_amd64.whl.metadata (5.1 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.5.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: pydantic>=2.0 in C:\Users\nehar\anaconda3\Lib\site-packages (from chromadb) (2.13.4)
# Requirement already satisfied: pydantic-settings>=2.0 in C:\Users\nehar\anaconda3\Lib\site-packages (from chromadb) (2.14.1)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.4.3-cp311-cp311-win_amd64.whl.metadata (9.1 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvicorn-0.46.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: numpy>=1.22.5 in C:\Users\nehar\anaconda3\Lib\site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in C:\Users\nehar\anaconda3\Lib\site-packages (from chromadb) (4.15.0)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.26.0-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.41.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.41.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.41.1-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in C:\Users\nehar\anaconda3\Lib\site-packages (from chromadb) (0.19.1)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading pypika-0.51.1-py2.py3-none-any.whl.metadata (51 kB)
# Requirement already satisfied: tqdm>=4.65.0 in C:\Users\nehar\anaconda3\Lib\site-packages (from chromadb) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in C:\Users\nehar\anaconda3\Lib\site-packages (from chromadb) (7.4.0)
# Collecting importlib-resources (from chromadb)
#   Downloading importlib_resources-7.1.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: grpcio>=1.58.0 in C:\Users\nehar\anaconda3\Lib\site-packages (from chromadb) (1.62.2)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-5.0.0-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in C:\Users\nehar\anaconda3\Lib\site-packages (from chromadb) (0.12.5)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-35.0.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tenacity>=8.2.3 in C:\Users\nehar\anaconda3\Lib\site-packages (from chromadb) (9.1.4)
# Requirement already satisfied: pyyaml>=6.0.0 in C:\Users\nehar\anaconda3\Lib\site-packages (from chromadb) (6.0.3)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.2.1-cp311-cp311-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: orjson>=3.9.12 in C:\Users\nehar\anaconda3\Lib\site-packages (from chromadb) (3.11.9)
# Requirement already satisfied: httpx>=0.27.0 in C:\Users\nehar\anaconda3\Lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in C:\Users\nehar\anaconda3\Lib\site-packages (from chromadb) (13.5.2)
# Requirement already satisfied: jsonschema>=4.19.0 in C:\Users\nehar\anaconda3\Lib\site-packages (from chromadb) (4.19.2)
# Requirement already satisfied: packaging>=24.0 in C:\Users\nehar\anaconda3\Lib\site-packages (from build>=1.0.3->chromadb) (26.2)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in C:\Users\nehar\anaconda3\Lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in C:\Users\nehar\anaconda3\Lib\site-packages (from httpx>=0.27.0->chromadb) (4.13.0)
# Requirement already satisfied: certifi in C:\Users\nehar\anaconda3\Lib\site-packages (from httpx>=0.27.0->chromadb) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\nehar\anaconda3\Lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in C:\Users\nehar\anaconda3\Lib\site-packages (from httpx>=0.27.0->chromadb) (3.15)
# Requirement already satisfied: h11>=0.16 in C:\Users\nehar\anaconda3\Lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\nehar\anaconda3\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\nehar\anaconda3\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\nehar\anaconda3\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in C:\Users\nehar\anaconda3\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.10.6)
# Requirement already satisfied: six>=1.9.0 in C:\Users\nehar\anaconda3\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in C:\Users\nehar\anaconda3\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in C:\Users\nehar\anaconda3\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in C:\Users\nehar\anaconda3\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.34.0)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in C:\Users\nehar\anaconda3\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.7.0)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Requirement already satisfied: flatbuffers in C:\Users\nehar\anaconda3\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in C:\Users\nehar\anaconda3\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (4.24.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in C:\Users\nehar\anaconda3\Lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.0.1)
# Requirement already satisfied: zipp>=0.5 in C:\Users\nehar\anaconda3\Lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Collecting googleapis-common-protos~=1.57 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading googleapis_common_protos-1.75.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting grpcio>=1.58.0 (from chromadb)
#   Downloading grpcio-1.80.0-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.41.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.41.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.41.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.41.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb)
#   Downloading protobuf-6.33.6-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting opentelemetry-semantic-conventions==0.62b1 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.62b1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\nehar\anaconda3\Lib\site-packages (from pydantic>=2.0->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\nehar\anaconda3\Lib\site-packages (from pydantic>=2.0->chromadb) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\nehar\anaconda3\Lib\site-packages (from pydantic>=2.0->chromadb) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in C:\Users\nehar\anaconda3\Lib\site-packages (from pydantic-settings>=2.0->chromadb) (1.0.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\nehar\anaconda3\Lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\nehar\anaconda3\Lib\site-packages (from rich>=10.11.0->chromadb) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\nehar\anaconda3\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in C:\Users\nehar\anaconda3\Lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.24.6)
# Requirement already satisfied: filelock in C:\Users\nehar\anaconda3\Lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\nehar\anaconda3\Lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.9.0)
# Requirement already satisfied: click>=8.0.0 in C:\Users\nehar\anaconda3\Lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\nehar\anaconda3\Lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.7.1-cp311-cp311-win_amd64.whl.metadata (3.6 kB)
# Collecting watchfiles>=0.20 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-1.1.1-cp311-cp311-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading websockets-16.0-cp311-cp311-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\nehar\anaconda3\Lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.7)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib->kubernetes>=28.1.0->chromadb)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Downloading chromadb-1.5.9-cp39-abi3-win_amd64.whl (23.5 MB)
#    ---------------------------------------- 0.0/23.5 MB ? eta -:--:--
#    - -------------------------------------- 1.0/23.5 MB 6.3 MB/s eta 0:00:04
#    --- ------------------------------------ 2.1/23.5 MB 5.3 MB/s eta 0:00:05
#    ----- ---------------------------------- 3.1/23.5 MB 5.0 MB/s eta 0:00:05
#    ------- -------------------------------- 4.2/23.5 MB 5.2 MB/s eta 0:00:04
#    --------- ------------------------------ 5.5/23.5 MB 5.2 MB/s eta 0:00:04
#    ----------- ---------------------------- 6.6/23.5 MB 5.3 MB/s eta 0:00:04
#    ------------ --------------------------- 7.1/23.5 MB 5.3 MB/s eta 0:00:04
#    -------------- ------------------------- 8.4/23.5 MB 5.0 MB/s eta 0:00:04
#    --------------- ------------------------ 9.2/23.5 MB 4.9 MB/s eta 0:00:03
#    ---------------- ----------------------- 10.0/23.5 MB 4.8 MB/s eta 0:00:03
#    ------------------- -------------------- 11.3/23.5 MB 4.8 MB/s eta 0:00:03
#    -------------------- ------------------- 11.8/23.5 MB 4.6 MB/s eta 0:00:03
#    ---------------------- ----------------- 13.1/23.5 MB 4.7 MB/s eta 0:00:03
#    ------------------------ --------------- 14.2/23.5 MB 4.8 MB/s eta 0:00:02
#    ------------------------- -------------- 15.2/23.5 MB 4.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 16.5/23.5 MB 4.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 17.6/23.5 MB 4.8 MB/s eta 0:00:02
#    ------------------------------- -------- 18.6/23.5 MB 4.9 MB/s eta 0:00:02
#    --------------------------------- ------ 19.9/23.5 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 20.4/23.5 MB 4.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 21.0/23.5 MB 4.8 MB/s eta 0:00:01
#    ------------------------------------ --- 21.8/23.5 MB 4.7 MB/s eta 0:00:01
#    -------------------------------------- - 22.8/23.5 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 23.5/23.5 MB 4.6 MB/s  0:00:05
# Downloading bcrypt-5.0.0-cp39-abi3-win_amd64.whl (150 kB)
# Downloading build-1.5.0-py3-none-any.whl (26 kB)
# Downloading kubernetes-35.0.0-py2.py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    --------------- ------------------------ 0.8/2.0 MB 5.6 MB/s eta 0:00:01
#    ------------------------------------ --- 1.8/2.0 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 4.7 MB/s  0:00:00
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading mmh3-5.2.1-cp311-cp311-win_amd64.whl (41 kB)
# Downloading onnxruntime-1.26.0-cp311-cp311-win_amd64.whl (13.0 MB)
#    ---------------------------------------- 0.0/13.0 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/13.0 MB 5.6 MB/s eta 0:00:03
#    ------ --------------------------------- 2.1/13.0 MB 4.7 MB/s eta 0:00:03
#    -------- ------------------------------- 2.9/13.0 MB 4.9 MB/s eta 0:00:03
#    ------------ --------------------------- 4.2/13.0 MB 4.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.2/13.0 MB 4.9 MB/s eta 0:00:02
#    ------------------ --------------------- 6.0/13.0 MB 4.8 MB/s eta 0:00:02
#    -------------------- ------------------- 6.8/13.0 MB 4.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 7.6/13.0 MB 4.6 MB/s eta 0:00:02
#    -------------------------- ------------- 8.7/13.0 MB 4.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.7/13.0 MB 4.5 MB/s eta 0:00:01
#    --------------------------------- ------ 10.7/13.0 MB 4.6 MB/s eta 0:00:01
#    ------------------------------------ --- 11.8/13.0 MB 4.6 MB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.0 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 13.0/13.0 MB 4.6 MB/s  0:00:02
# Downloading opentelemetry_api-1.41.1-py3-none-any.whl (69 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.41.1-py3-none-any.whl (20 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.41.1-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.41.1-py3-none-any.whl (72 kB)
# Downloading googleapis_common_protos-1.75.0-py3-none-any.whl (300 kB)
# Downloading grpcio-1.80.0-cp311-cp311-win_amd64.whl (4.9 MB)
#    ---------------------------------------- 0.0/4.9 MB ? eta -:--:--
#    -------- ------------------------------- 1.0/4.9 MB 6.3 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.1/4.9 MB 5.9 MB/s eta 0:00:01
#    ------------------------- -------------- 3.1/4.9 MB 5.4 MB/s eta 0:00:01
#    ------------------------------------ --- 4.5/4.9 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 4.9/4.9 MB 5.1 MB/s  0:00:00
# Downloading opentelemetry_sdk-1.41.1-py3-none-any.whl (180 kB)
# Downloading opentelemetry_semantic_conventions-0.62b1-py3-none-any.whl (231 kB)
# Downloading protobuf-6.33.6-cp310-abi3-win_amd64.whl (437 kB)
# Downloading pybase64-1.4.3-cp311-cp311-win_amd64.whl (35 kB)
# Downloading pypika-0.51.1-py2.py3-none-any.whl (60 kB)
# Downloading uvicorn-0.46.0-py3-none-any.whl (70 kB)
# Downloading httptools-0.7.1-cp311-cp311-win_amd64.whl (86 kB)
# Downloading watchfiles-1.1.1-cp311-cp311-win_amd64.whl (287 kB)
# Downloading websockets-16.0-cp311-cp311-win_amd64.whl (178 kB)
# Downloading importlib_resources-7.1.0-py3-none-any.whl (37 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Installing collected packages: pypika, durationpy, websockets, pyproject_hooks, pybase64, protobuf, oauthlib, mmh3, importlib-resources, httptools, grpcio, bcrypt, watchfiles, uvicorn, requests-oauthlib, opentelemetry-proto, opentelemetry-api, onnxruntime, googleapis-common-protos, build, opentelemetry-semantic-conventions, opentelemetry-exporter-otlp-proto-common, kubernetes, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-grpc, chromadb
#
#    ----------------------------------------  0/26 [pypika]
#    --- ------------------------------------  2/26 [websockets]
#    --- ------------------------------------  2/26 [websockets]
#    ------ ---------------------------------  4/26 [pybase64]
#   Attempting uninstall: protobuf
#    ------ ---------------------------------  4/26 [pybase64]
#     Found existing installation: protobuf 4.24.3
#    ------ ---------------------------------  4/26 [pybase64]
#    ------- --------------------------------  5/26 [protobuf]
#     Uninstalling protobuf-4.24.3:
#    ------- --------------------------------  5/26 [protobuf]
#       Successfully uninstalled protobuf-4.24.3
#    ------- --------------------------------  5/26 [protobuf]
#    ------- --------------------------------  5/26 [protobuf]
#    ------- --------------------------------  5/26 [protobuf]
#    ------- --------------------------------  5/26 [protobuf]
#    ------- --------------------------------  5/26 [protobuf]
#    --------- ------------------------------  6/26 [oauthlib]
#    --------- ------------------------------  6/26 [oauthlib]
#    --------- ------------------------------  6/26 [oauthlib]
#    ------------ ---------------------------  8/26 [importlib-resources]
#    ------------ ---------------------------  8/26 [importlib-resources]
#   Attempting uninstall: grpcio
#    ------------ ---------------------------  8/26 [importlib-resources]
#     Found existing installation: grpcio 1.62.2
#    ------------ ---------------------------  8/26 [importlib-resources]
#     Uninstalling grpcio-1.62.2:
#    ------------ ---------------------------  8/26 [importlib-resources]
#    --------------- ------------------------ 10/26 [grpcio]
#       Successfully uninstalled grpcio-1.62.2
#    --------------- ------------------------ 10/26 [grpcio]
#    --------------- ------------------------ 10/26 [grpcio]
#    --------------- ------------------------ 10/26 [grpcio]
#    --------------- ------------------------ 10/26 [grpcio]
#   Attempting uninstall: bcrypt
#    --------------- ------------------------ 10/26 [grpcio]
#     Found existing installation: bcrypt 3.2.0
#    --------------- ------------------------ 10/26 [grpcio]
#     Uninstalling bcrypt-3.2.0:
#    --------------- ------------------------ 10/26 [grpcio]
#       Successfully uninstalled bcrypt-3.2.0
#    --------------- ------------------------ 10/26 [grpcio]
#    ---------------- ----------------------- 11/26 [bcrypt]
#    ---------------- ----------------------- 11/26 [bcrypt]
#    ---------------- ----------------------- 11/26 [bcrypt]
#    ---------------- ----------------------- 11/26 [bcrypt]
#    ---------------- ----------------------- 11/26 [bcrypt]
#    ---------------- ----------------------- 11/26 [bcrypt]
#    ---------------- ----------------------- 11/26 [bcrypt]
#    ---------------- ----------------------- 11/26 [bcrypt]
#    ---------------- ----------------------- 11/26 [bcrypt]
#    ---------------- ----------------------- 11/26 [bcrypt]
#    ---------------- ----------------------- 11/26 [bcrypt]
#    ---------------- ----------------------- 11/26 [bcrypt]
#    ---------------- ----------------------- 11/26 [bcrypt]
#    ---------------- ----------------------- 11/26 [bcrypt]
#    ---------------- ----------------------- 11/26 [bcrypt]
#    ---------------- ----------------------- 11/26 [bcrypt]
#    ---------------- ----------------------- 11/26 [bcrypt]
#    ---------------- ----------------------- 11/26 [bcrypt]
#    ------------------ --------------------- 12/26 [watchfiles]
#    -------------------- ------------------- 13/26 [uvicorn]
#    --------------------- ------------------ 14/26 [requests-oauthlib]
#    ----------------------- ---------------- 15/26 [opentelemetry-proto]
#    ------------------------ --------------- 16/26 [opentelemetry-api]
#    ------------------------ --------------- 16/26 [opentelemetry-api]
#    -------------------------- ------------- 17/26 [onnxruntime]
#    -------------------------- ------------- 17/26 [onnxruntime]
#    -------------------------- ------------- 17/26 [onnxruntime]
#    -------------------------- ------------- 17/26 [onnxruntime]
#    -------------------------- ------------- 17/26 [onnxruntime]
#    -------------------------- ------------- 17/26 [onnxruntime]
#    -------------------------- ------------- 17/26 [onnxruntime]
#    -------------------------- ------------- 17/26 [onnxruntime]
#    -------------------------- ------------- 17/26 [onnxruntime]
#    -------------------------- ------------- 17/26 [onnxruntime]
#    -------------------------- ------------- 17/26 [onnxruntime]
#    -------------------------- ------------- 17/26 [onnxruntime]
#    -------------------------- ------------- 17/26 [onnxruntime]
#    -------------------------- ------------- 17/26 [onnxruntime]
#    -------------------------- ------------- 17/26 [onnxruntime]
#    -------------------------- ------------- 17/26 [onnxruntime]
#    -------------------------- ------------- 17/26 [onnxruntime]
#    -------------------------- ------------- 17/26 [onnxruntime]
#    --------------------------- ------------ 18/26 [googleapis-common-protos]
#    --------------------------- ------------ 18/26 [googleapis-common-protos]
#    --------------------------- ------------ 18/26 [googleapis-common-protos]
#    --------------------------- ------------ 18/26 [googleapis-common-protos]
#    ------------------------- ------- 20/26 [opentelemetry-semantic-conventions]
#    ------------------------- ------- 20/26 [opentelemetry-semantic-conventions]
#    ------------------------- ------- 20/26 [opentelemetry-semantic-conventions]
#    ------------------------- ------- 20/26 [opentelemetry-semantic-conventions]
#    ------------------------- ------- 20/26 [opentelemetry-semantic-conventions]
#    ------------------------- ------- 20/26 [opentelemetry-semantic-conventions]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    ----------------------------------- ---- 23/26 [opentelemetry-sdk]
#    ----------------------------------- ---- 23/26 [opentelemetry-sdk]
#    ----------------------------------- ---- 23/26 [opentelemetry-sdk]
#    ----------------------------------- ---- 23/26 [opentelemetry-sdk]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    ---------------------------------------- 26/26 [chromadb]
#
# Successfully installed bcrypt-5.0.0 build-1.5.0 chromadb-1.5.9 durationpy-0.10 googleapis-common-protos-1.75.0 grpcio-1.80.0 httptools-0.7.1 importlib-resources-7.1.0 kubernetes-35.0.0 mmh3-5.2.1 oauthlib-3.3.1 onnxruntime-1.26.0 opentelemetry-api-1.41.1 opentelemetry-exporter-otlp-proto-common-1.41.1 opentelemetry-exporter-otlp-proto-grpc-1.41.1 opentelemetry-proto-1.41.1 opentelemetry-sdk-1.41.1 opentelemetry-semantic-conventions-0.62b1 protobuf-6.33.6 pybase64-1.4.3 pypika-0.51.1 pyproject_hooks-1.2.0 requests-oauthlib-2.0.0 uvicorn-0.46.0 watchfiles-1.1.1 websockets-16.0
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\nehar\anaconda3\Lib\site-packages\~crypt'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.38.0 requires packaging<25,>=20, but you have packaging 26.2 which is incompatible.
# streamlit 1.38.0 requires protobuf<6,>=3.20, but you have protobuf 6.33.6 which is incompatible.
# streamlit 1.38.0 requires tenacity<9,>=8.1.0, but you have tenacity 9.1.4 which is incompatible.
# tensorflow-intel 2.17.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 6.33.6 which is incompatible.

# %%
import chromadb

client = chromadb.Client()
collection = client.create_collection(name="my_collection")

# %%
collection.add(
    documents=[
        "This document is about New York",
        "This document is about Delhi"
    ],
    ids = ['id1', 'id2']
)
# Out:
# C:\Users\nehar\.cache\chroma\onnx_models\all-MiniLM-L6-v2\onnx.tar.gz: 100%|█████| 79.3M/79.3M [00:19<00:00, 4.23MiB/s]

# %%
all_docs = collection.get()
all_docs
# Out:
# {'ids': ['id1', 'id2'],
#  'embeddings': None,
#  'documents': ['This document is about New York',
#   'This document is about Delhi'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [None, None]}

# %%
documents = collection.get(ids=["id1"])
documents
# Out:
# {'ids': ['id1'],
#  'embeddings': None,
#  'documents': ['This document is about New York'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [None]}

# %%
results = collection.query(
    query_texts=['Query is about mango'],
    n_results=2
)
results
# Out:
# {'ids': [['id4', 'id3']],
#  'embeddings': None,
#  'documents': [['This document is about Delhi',
#    'This document is about New York']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[{'url': 'https://en.wikipedia.org/wiki/New_Delhi'},
#    {'url': 'https://en.wikipedia.org/wiki/New_York_City'}]],
#  'distances': [[1.574796199798584, 1.9014835357666016]]}

# %%
collection.delete(ids=all_docs['ids'])
collection.get()
# Out:
# {'ids': [],
#  'embeddings': None,
#  'documents': [],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': []}

# %%
collection.add(
    documents=[
        "This document is about New York",
        "This document is about Delhi"
    ],
    ids=["id3", "id4"],
    metadatas=[
        {"url": "https://en.wikipedia.org/wiki/New_York_City"},
        {"url": "https://en.wikipedia.org/wiki/New_Delhi"}
    ]
)

# %%
results = collection.query(
    query_texts=["Query is about Chhole Bhature"],
    n_results=2
)
results
# Out:
# {'ids': [['id4', 'id3']],
#  'embeddings': None,
#  'documents': [['This document is about Delhi',
#    'This document is about New York']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[{'url': 'https://en.wikipedia.org/wiki/New_Delhi'},
#    {'url': 'https://en.wikipedia.org/wiki/New_York_City'}]],
#  'distances': [[1.5588479042053223, 1.8114913702011108]]}
