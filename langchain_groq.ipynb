# %%
# %pip install -qU langchain-groq
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_groq import ChatGroq

# %%
# %pip install "numpy<2"
# Out:
# Requirement already satisfied: numpy<2 in C:\Users\nehar\anaconda3\Lib\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy
print(numpy.__version__) 
# It should now start with 1.26
# Out:
# 2.4.4

# %%
from langchain_groq import ChatGroq
print("Everything is finally working!")
# Out:
# Everything is finally working!

# %%
llm = ChatGroq(
    groq_api_key='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',
    model= "llama-3.3-70b-versatile",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
    #other params...
)

# %%
llm = ChatGroq(
    temperature=0, 
    groq_api_key='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', 
    model_name="llama-3.3-70b-versatile"
)
response = llm.invoke("Dileep raj kannada actor")
print(response.content)
# Out:
# Dileep Raj is a Kannada film actor who has appeared in numerous films, primarily in supporting roles. He is known for his versatility and has played a wide range of characters throughout his career.
#
# Some of his notable films include:
#
# 1. **Mungaru Male** (2006) - a romantic comedy-drama film that became a huge success and helped establish Dileep Raj as a recognizable face in Kannada cinema.
# 2. **Milana** (2007) - a romantic drama film that starred Puneeth Rajkumar and Parvathy Thiruvothu.
# 3. **Arasu** (2007) - an action-drama film that starred Puneeth Rajkumar and Ramya.
# 4. **Bindaas** (2008) - a romantic comedy film that starred Puneeth Rajkumar and Hansika Motwani.
# 5. **Jackie** (2010) - an action-drama film that starred Puneeth Rajkumar and Bhavana.
#
# Dileep Raj has worked with many prominent directors in the Kannada film industry, including Yogaraj Bhat, Prakash Raj, and Soori. He has also shared screen space with several leading actors, including Puneeth Rajkumar, Sudeep, and Darshan.
#
# While Dileep Raj has not achieved leading man status, he has carved out a niche for himself as a reliable and talented supporting actor in Kannada cinema. His ability to play a wide range of roles has made him a sought-after actor in the industry.
